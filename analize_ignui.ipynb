# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import missingno as msno 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"E:/igno_duomenys.csv")

# %%
#duomenu pasitvarkymas
df=df.drop('Unnamed: 16', axis=1)
df.dropna(inplace=True)

# %%
df.tail()
# Out:
#             XLV         XLY        XLP        XLE        XLF         XLI  \
# 272  134.240005  171.679993  73.000000  89.900002  34.590000  108.980003
# 273  128.330002  160.020004  68.650002  90.269997  33.060001  101.089996
# 274  124.389999  152.990005  67.910004  85.730003  32.419998   98.459999
# 275  131.130005  168.059998  70.610001  84.480003  35.840000  107.150002
# 276  136.039993  178.250000  71.769997  84.430000  37.500000  113.230003
#
#             XLK        XLU        XLB    SP500          BVP      VKI    AKA  \
# 272  176.759995  63.290001  83.680000  4530.60  82900.41352  307.288 -3.931
# 273  164.009995  58.590000  78.239998  4284.52  82611.60819  307.531  6.987
# 274  164.300003  59.770000  75.949997  4201.27  83202.59713  308.024  2.385
# 275  184.679993  62.790001  82.529999  4559.43  83864.41686  308.742  1.061
# 276  189.860001  63.060001  84.919998  4745.20  83311.47520  309.685 -1.386
#
#        JAV   NL   BPN
# 272 -1.177  3.8  5.33
# 273 -0.807  3.8  5.33
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 277 entries, 0 to 276
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   XLV     277 non-null    float64
#  1   XLY     277 non-null    float64
#  2   XLP     277 non-null    float64
#  3   XLE     277 non-null    float64
#  4   XLF     277 non-null    float64
#  5   XLI     277 non-null    float64
#  6   XLK     277 non-null    float64
#  7   XLU     277 non-null    float64
#  8   XLB     277 non-null    float64
#  9   SP500   277 non-null    float64
#  10  BVP     277 non-null    float64
#  11  VKI     277 non-null    float64
#  12  AKA     277 non-null    float64
#  13  JAV     277 non-null    float64
#  14  NL      277 non-null    float64
#  15  BPN     277 non-null    float64
# dtypes: float64(16)
# memory usage: 36.8 KB

# %%
independent=df.columns[10:].tolist()

# %%
print(independent)
# Out:
# ['BVP', 'VKI', 'AKA', 'JAV', 'NL', 'BPN']

# %%
x=df[independent]
y=df['XLV']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLV   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     934.3
# Date:                Thu, 02 May 2024   Prob (F-statistic):          2.18e-177
# Time:                        23:21:28   Log-Likelihood:                -957.18
# No. Observations:                 277   AIC:                             1928.
# Df Residuals:                     270   BIC:                             1954.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         52.2028     11.766      4.437      0.000      29.037      75.368
# ...

# %%
indep=[ 'VKI', 'BPN']
x=df[indep]
y=df['XLV']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLV   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     852.9
# Date:                Thu, 02 May 2024   Prob (F-statistic):          2.15e-118
# Time:                        23:21:40   Log-Likelihood:                -1109.9
# No. Observations:                 277   AIC:                             2226.
# Df Residuals:                     274   BIC:                             2237.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.0492      5.619    -29.906      0.000    -179.111    -156.987
# ...

# %%
x=df[independent]
y=df['XLY']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLY   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     789.6
# Date:                Thu, 02 May 2024   Prob (F-statistic):          5.12e-168
# Time:                        23:21:44   Log-Likelihood:                -1067.5
# No. Observations:                 277   AIC:                             2149.
# Df Residuals:                     270   BIC:                             2174.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        155.0408     17.521      8.849      0.000     120.547     189.535
# ...

# %%
indep=[ 'VKI', 'NL', 'BPN']
x=df[indep]
y=df['XLY']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLY   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     543.4
# Date:                Thu, 02 May 2024   Prob (F-statistic):          9.39e-115
# Time:                        23:21:49   Log-Likelihood:                -1203.0
# No. Observations:                 277   AIC:                             2414.
# Df Residuals:                     273   BIC:                             2428.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -160.3849     11.140    -14.398      0.000    -182.315    -138.454
# ...

# %%
x=df[independent]
y=df['XLP']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLP   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     836.2
# Date:                Thu, 02 May 2024   Prob (F-statistic):          3.35e-171
# Time:                        23:22:05   Log-Likelihood:                -778.06
# No. Observations:                 277   AIC:                             1570.
# Df Residuals:                     270   BIC:                             1595.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.8831      6.163      1.604      0.110      -2.251      22.018
# ...

# %%
indep=[ 'VKI', 'JAV','NL', 'BPN']
x=df[indep]
y=df['XLP']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLP   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     1043.
# Date:                Thu, 02 May 2024   Prob (F-statistic):          1.25e-163
# Time:                        23:22:15   Log-Likelihood:                -803.10
# No. Observations:                 277   AIC:                             1616.
# Df Residuals:                     272   BIC:                             1634.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -24.0183      4.427     -5.425      0.000     -32.734     -15.303
# ...

# %%
x=df[independent]
y=df['XLE']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLE   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                     130.2
# Date:                Thu, 02 May 2024   Prob (F-statistic):           1.06e-76
# Time:                        23:22:25   Log-Likelihood:                -1033.2
# No. Observations:                 277   AIC:                             2080.
# Df Residuals:                     270   BIC:                             2106.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -289.4922     15.482    -18.699      0.000    -319.973    -259.012
# ...

# %%
indep=[ 'VKI', 'JAV','BPN']
x=df[indep]
y=df['XLE']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLE   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     65.71
# Date:                Thu, 02 May 2024   Prob (F-statistic):           5.16e-32
# Time:                        23:29:31   Log-Likelihood:                -1146.2
# No. Observations:                 277   AIC:                             2300.
# Df Residuals:                     273   BIC:                             2315.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -71.0264     13.990     -5.077      0.000     -98.568     -43.485
# ...

# %%
x=df[independent]
y=df['XLF']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLF   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     288.0
# Date:                Thu, 02 May 2024   Prob (F-statistic):          3.15e-114
# Time:                        23:22:41   Log-Likelihood:                -673.98
# No. Observations:                 277   AIC:                             1362.
# Df Residuals:                     270   BIC:                             1387.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         68.0033      4.233     16.065      0.000      59.670      76.337
# ...

# %%
indep=['VKI',  'BPN']
x=df[indep]
y=df['XLF']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLF   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     168.3
# Date:                Thu, 02 May 2024   Prob (F-statistic):           2.07e-48
# Time:                        23:32:40   Log-Likelihood:                -840.19
# No. Observations:                 277   AIC:                             1686.
# Df Residuals:                     274   BIC:                             1697.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.9396      2.123     -4.212      0.000     -13.118      -4.761
# ...

# %%
x=df[independent]
y=df['XLI']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLI   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     998.9
# Date:                Thu, 02 May 2024   Prob (F-statistic):          3.94e-181
# Time:                        22:37:03   Log-Likelihood:                -857.25
# No. Observations:                 277   AIC:                             1728.
# Df Residuals:                     270   BIC:                             1754.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.4308      8.203      2.856      0.005       7.281      39.581
# ...

# %%
indep=['VKI', 'NL', 'BPN']
x=df[indep]
y=df['XLI']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLI   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     1109.
# Date:                Thu, 02 May 2024   Prob (F-statistic):          1.59e-152
# Time:                        23:33:25   Log-Likelihood:                -935.47
# No. Observations:                 277   AIC:                             1879.
# Df Residuals:                     273   BIC:                             1893.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -74.3535      4.241    -17.531      0.000     -82.703     -66.004
# ...

# %%
x=df[independent]
y=df['XLK']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLK   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     473.5
# Date:                Thu, 02 May 2024   Prob (F-statistic):          3.85e-140
# Time:                        22:38:33   Log-Likelihood:                -1107.9
# No. Observations:                 277   AIC:                             2230.
# Df Residuals:                     270   BIC:                             2255.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         57.7845     20.273      2.850      0.005      17.871      97.698
# ...

# %%
indep=['VKI',  'NL', 'BPN']
x=df[indep]
y=df['XLK']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLK   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     380.2
# Date:                Thu, 02 May 2024   Prob (F-statistic):           3.87e-97
# Time:                        23:34:06   Log-Likelihood:                -1218.6
# No. Observations:                 277   AIC:                             2445.
# Df Residuals:                     273   BIC:                             2460.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -196.6419     11.788    -16.681      0.000    -219.849    -173.434
# ...

# %%
x=df[independent]
y=df['XLU']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLU   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     527.1
# Date:                Thu, 02 May 2024   Prob (F-statistic):          6.67e-146
# Time:                        22:39:56   Log-Likelihood:                -782.84
# No. Observations:                 277   AIC:                             1580.
# Df Residuals:                     270   BIC:                             1605.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.3282      6.271      3.082      0.002       6.983      31.674
# ...

# %%
indep=['BVP', 'JAV', 'NL', 'BPN']
x=df[indep]
y=df['XLU']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLU   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     786.1
# Date:                Thu, 02 May 2024   Prob (F-statistic):          4.35e-148
# Time:                        22:40:51   Log-Likelihood:                -784.52
# No. Observations:                 277   AIC:                             1579.
# Df Residuals:                     272   BIC:                             1597.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.8377      3.450      2.852      0.005       3.046      16.629
# ...

# %%
x=df[independent]
y=df['XLB']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLB   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     764.3
# Date:                Thu, 02 May 2024   Prob (F-statistic):          3.24e-166
# Time:                        22:41:36   Log-Likelihood:                -803.91
# No. Observations:                 277   AIC:                             1622.
# Df Residuals:                     270   BIC:                             1647.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.9916      6.766     -1.329      0.185     -22.313       4.329
# ...

# %%
indep=['VKI', 'JAV']
x=df[indep]
y=df['XLB']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    XLB   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     1109.
# Date:                Thu, 02 May 2024   Prob (F-statistic):          4.38e-132
# Time:                        23:34:57   Log-Likelihood:                -898.32
# No. Observations:                 277   AIC:                             1803.
# Df Residuals:                     274   BIC:                             1814.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.0731      3.312    -20.858      0.000     -75.592     -62.554
# ...

# %% [markdown]
# **Keistai su situo gavos, intercept nepatikimas. Bet gal prametus kas ten su kuo stipriai koreliuoja pageres reikalai**

# %%
x=df[independent]
y=df['SP500']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  SP500   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     823.1
# Date:                Thu, 02 May 2024   Prob (F-statistic):          2.52e-170
# Time:                        22:51:21   Log-Likelihood:                -1918.5
# No. Observations:                 277   AIC:                             3851.
# Df Residuals:                     270   BIC:                             3876.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2065.5830    378.251      5.461      0.000    1320.887    2810.279
# ...

# %%
indep=['VKI', 'NL']
x=df[indep]
y=df['SP500']

x=sm.add_constant(x)
model=sm.OLS(y, x).fit()
predictions=model.predict(x)
print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  SP500   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                     1034.
# Date:                Thu, 02 May 2024   Prob (F-statistic):          2.27e-128
# Time:                        23:35:24   Log-Likelihood:                -2031.2
# No. Observations:                 277   AIC:                             4068.
# Df Residuals:                     274   BIC:                             4079.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3480.5331    185.603    -18.753      0.000   -3845.922   -3115.145
# ...

# %%
correlation_matrix = df.corr(method='pearson')


plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Lower Triangle Correlation Matrix')
plt.show()
